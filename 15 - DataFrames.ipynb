# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
import webbrowser
website = 'http://en.wikipedia.org/wiki/NFL_win-loss_records'
webbrowser.open(website)
# Out:
# True

# %%
nfl_frame = pd.read_clipboard(sep='\t+', engine='python')

# %%
nfl_frame
# Out:
#     Rank                  Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0      1         Chicago Bears  741   555    42  0.570              1920
# 1      2        Dallas Cowboys  480   364     6  0.568              1960
# 2      3     Green Bay Packers  720   547    37  0.566              1921
# 3      4        Miami Dolphins  429   335     4  0.561              1966
# 4      5  New England Patriots  462   381     9  0.548              1960
# 5      6   San Francisco 49ers  520   436    14  0.543              1950
# 6      7      Baltimore Ravens  173   146     1  0.542              1996
# 7      7     Minnesota Vikings  449   379    10  0.542              1961
# 8      7       New York Giants  673   567    33  0.542              1925
# 9     10        Denver Broncos  456   386    10  0.541              1960
# 10    11    Indianapolis Colts  494   433     7  0.533              1953
#
#    Total Games    Divison
# 0        1,338  NFC North
# 1          850   NFC East
# ...

# %%
nfl_frame.columns
# Out:
# Index(['Rank', 'Team', 'Won', 'Lost', 'Tied', 'Pct.', 'First NFL Season',
#        'Total Games', 'Divison'],
#       dtype='object')

# %%
DataFrame(nfl_frame, columns = ['Team', 'Won', 'Lost'])
# Out:
#                     Team  Won  Lost
# 0          Chicago Bears  741   555
# 1         Dallas Cowboys  480   364
# 2      Green Bay Packers  720   547
# 3         Miami Dolphins  429   335
# 4   New England Patriots  462   381
# 5    San Francisco 49ers  520   436
# 6       Baltimore Ravens  173   146
# 7      Minnesota Vikings  449   379
# 8        New York Giants  673   567
# 9         Denver Broncos  456   386
# 10    Indianapolis Colts  494   433

# %%
DataFrame(nfl_frame, columns = ['Team', 'Won', 'Lost', 'Stadium'])
# Out:
#                     Team  Won  Lost  Stadium
# 0          Chicago Bears  741   555      NaN
# 1         Dallas Cowboys  480   364      NaN
# 2      Green Bay Packers  720   547      NaN
# 3         Miami Dolphins  429   335      NaN
# 4   New England Patriots  462   381      NaN
# 5    San Francisco 49ers  520   436      NaN
# 6       Baltimore Ravens  173   146      NaN
# 7      Minnesota Vikings  449   379      NaN
# 8        New York Giants  673   567      NaN
# 9         Denver Broncos  456   386      NaN
# 10    Indianapolis Colts  494   433      NaN

# %%
nfl_frame.columns
# Out:
# Index(['Rank', 'Team', 'Won', 'Lost', 'Tied', 'Pct.', 'First NFL Season',
#        'Total Games', 'Divison'],
#       dtype='object')

# %%
nfl_frame.Team
# Out:
# 0            Chicago Bears
# 1           Dallas Cowboys
# 2        Green Bay Packers
# 3           Miami Dolphins
# 4     New England Patriots
# 5      San Francisco 49ers
# 6         Baltimore Ravens
# 7        Minnesota Vikings
# 8          New York Giants
# 9           Denver Broncos
# 10      Indianapolis Colts
# Name: Team, dtype: object

# %%
nfl_frame.ix[3]
# Out:
# Rank                             4
# Team                Miami Dolphins
# Won                            429
# Lost                           335
# Tied                             4
# Pct.                         0.561
# First NFL Season              1966
# Total Games                    768
# Divison                   AFC East
# Name: 3, dtype: object

# %%
nfl_frame['Stadium'] = 'Best'

# %%
nfl_frame
# Out:
#     Rank                  Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0      1         Chicago Bears  741   555    42  0.570              1920
# 1      2        Dallas Cowboys  480   364     6  0.568              1960
# 2      3     Green Bay Packers  720   547    37  0.566              1921
# 3      4        Miami Dolphins  429   335     4  0.561              1966
# 4      5  New England Patriots  462   381     9  0.548              1960
# 5      6   San Francisco 49ers  520   436    14  0.543              1950
# 6      7      Baltimore Ravens  173   146     1  0.542              1996
# 7      7     Minnesota Vikings  449   379    10  0.542              1961
# 8      7       New York Giants  673   567    33  0.542              1925
# 9     10        Denver Broncos  456   386    10  0.541              1960
# 10    11    Indianapolis Colts  494   433     7  0.533              1953
#
#    Total Games    Divison Stadium
# 0        1,338  NFC North    Best
# ...

# %%
nfl_frame.Stadium = np.arange(11)

# %%
nfl_frame
# Out:
#     Rank                  Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0      1         Chicago Bears  741   555    42  0.570              1920
# 1      2        Dallas Cowboys  480   364     6  0.568              1960
# 2      3     Green Bay Packers  720   547    37  0.566              1921
# 3      4        Miami Dolphins  429   335     4  0.561              1966
# 4      5  New England Patriots  462   381     9  0.548              1960
# 5      6   San Francisco 49ers  520   436    14  0.543              1950
# 6      7      Baltimore Ravens  173   146     1  0.542              1996
# 7      7     Minnesota Vikings  449   379    10  0.542              1961
# 8      7       New York Giants  673   567    33  0.542              1925
# 9     10        Denver Broncos  456   386    10  0.541              1960
# 10    11    Indianapolis Colts  494   433     7  0.533              1953
#
#    Total Games    Divison  Stadium
# 0        1,338  NFC North        0
# ...

# %%
stadiums = Series(['Cancer','Virgo'], index=[2,5])

# %%
stadiums
# Out:
# 2    Cancer
# 5     Virgo
# dtype: object

# %%
nfl_frame['Stadium'] = stadiums

# %%
nfl_frame
# Out:
#     Rank                  Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0      1         Chicago Bears  741   555    42  0.570              1920
# 1      2        Dallas Cowboys  480   364     6  0.568              1960
# 2      3     Green Bay Packers  720   547    37  0.566              1921
# 3      4        Miami Dolphins  429   335     4  0.561              1966
# 4      5  New England Patriots  462   381     9  0.548              1960
# 5      6   San Francisco 49ers  520   436    14  0.543              1950
# 6      7      Baltimore Ravens  173   146     1  0.542              1996
# 7      7     Minnesota Vikings  449   379    10  0.542              1961
# 8      7       New York Giants  673   567    33  0.542              1925
# 9     10        Denver Broncos  456   386    10  0.541              1960
# 10    11    Indianapolis Colts  494   433     7  0.533              1953
#
#    Total Games    Divison Stadium
# 0        1,338  NFC North     NaN
# ...

# %%
del nfl_frame['Stadium']

# %%
nfl_frame
# Out:
#     Rank                  Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0      1         Chicago Bears  741   555    42  0.570              1920
# 1      2        Dallas Cowboys  480   364     6  0.568              1960
# 2      3     Green Bay Packers  720   547    37  0.566              1921
# 3      4        Miami Dolphins  429   335     4  0.561              1966
# 4      5  New England Patriots  462   381     9  0.548              1960
# 5      6   San Francisco 49ers  520   436    14  0.543              1950
# 6      7      Baltimore Ravens  173   146     1  0.542              1996
# 7      7     Minnesota Vikings  449   379    10  0.542              1961
# 8      7       New York Giants  673   567    33  0.542              1925
# 9     10        Denver Broncos  456   386    10  0.541              1960
# 10    11    Indianapolis Colts  494   433     7  0.533              1953
#
#    Total Games    Divison
# 0        1,338  NFC North
# 1          850   NFC East
# ...

# %%
data = {'City': ['Kaunas', 'Vilnius', 'Klaipeda'], 'Population': [234,546,123]}

# %%
data
# Out:
# {'City': ['Kaunas', 'Vilnius', 'Klaipeda'], 'Population': [234, 546, 123]}

# %%
city_frame = DataFrame(data)

# %%
city_frame
# Out:
#        City  Population
# 0    Kaunas         234
# 1   Vilnius         546
# 2  Klaipeda         123
